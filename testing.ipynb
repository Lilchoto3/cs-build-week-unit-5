# %%
import csv
points = []
with open('blobs.csv', newline='') as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        points.append([float(row[1]), float(row[2])])

print(points[:5])
# Out:
# [[2.585749067032938, -7.384446376655612], [3.496018744290417, -6.076837627281], [-0.3048257866183498, -6.981354940672796], [-4.681266596289631, -0.026217710479438994], [-0.839549287040303, -8.090403737633206]]

# %%
from kmeans.kmeansClusteringNoScipy import KMeans
kmeans = KMeans(n_clusters=3, max_iter=20, savealliters=True)
kmeans.fit(points)
print(kmeans.predict(points))
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# [1, 1, 0, 2, 0, 2, 0, 2, 2, 2, 0, 1, 0, 0, 0, 2, 1, 1, 0, 1, 1, 0, 0, 0, 0, 0, 2, 2, 1, 2, 1, 2, 0, 2, 0, 2, 1, 0, 2, 0, 1, 0, 1, 2, 1, 2, 1, 0, 1, 1, 0, 1, 1, 2, 0, 2, 1, 0, 2, 0, 0, 2, 2, 2, 0, 1, 1, 1, 0, 0, 0, 2, 2, 2, 2, 0, 1, 1, 0, 2, 0, 1, 0, 1, 1, 1, 1, 2, 2, 0, 1, 2, 2, 0, 0, 0, 2, 1, 2, 2]

# %%
# plot points with clusters to show it works
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(points, columns=['x','y'])
df['label'] = kmeans.predict(points)
df.head()

colors = {0:'tab:blue',
          1:'tab:orange', 
          2:'tab:green', 
          3:'tab:red', 
          4:'tab:purple',
          5:'tab:brown',
          6:'tab:pink', 
          7:'tab:gray'
}
fig, ax = plt.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
plt.show()
